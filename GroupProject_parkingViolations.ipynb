# %%
# !pip install pandas
# !pip install sodapy
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: sodapy in /usr/local/lib/python3.10/dist-packages (2.2.0)
# Requirement already satisfied: requests>=2.28.1 in /usr/local/lib/python3.10/dist-packages (from sodapy) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->sodapy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->sodapy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->sodapy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->sodapy) (2024.8.30)

# %%
from sodapy import Socrata
import pandas as pd
import time

# %%
# Initialize Socrata client
client = Socrata("data.cityofnewyork.us", "ql2o7kE6dAr27uzMyaLLF4nbl", timeout=60)
dataset_id = "nc67-uf89"
params = { # set the parameters and using where to set the limit
    "select": "plate, state, issue_date, violation_time, violation, fine_amount, penalty_amount, interest_amount, reduction_amount, payment_amount, amount_due, county, violation_status",
    "where": "issue_date >= '2022-01-01T00:00:00'",
    "limit": 5000,
}
record_count = 111000

# %%
from concurrent.futures import ThreadPoolExecutor
from tenacity import retry, stop_after_attempt, wait_fixed

# %%
@retry(stop=stop_after_attempt(5), wait=wait_fixed(5)) ## retry funtion to keep in loop and divide it by the chunk
def fetch_chunk(offset):
    return client.get(dataset_id, offset=offset, **params)

# Fetch data with retries
results, failed_offsets = [], []
for offset in range(0, record_count, params["limit"]):
    try:
        results.extend(fetch_chunk(offset))
    except Exception:
        failed_offsets.append(offset)

# Retry failed chunks
for offset in failed_offsets:
    try:
        results.extend(fetch_chunk(offset))
    except Exception:
        pass

# %%
# Turn results into a data frame
parking_df= pd.DataFrame.from_records(results)

# %%
parking_df.head(5)
# Out:
#       plate state               issue_date violation_time  \
# 0   AA96820    CT  2022-01-01T00:00:00.000         11:10A
# 1   GNV8795    NY  2022-01-01T00:00:00.000         11:42A
# 2    DFTE69    FL  2022-01-01T00:00:00.000         11:44A
# 3  T678645C    NY  2022-01-01T00:00:00.000         01:13A
# 4   67522MN    NY  2022-01-02T00:00:00.000         12:53P
#
#                         violation fine_amount penalty_amount interest_amount  \
# 0  NO STAND TAXI/FHV RELIEF STAND         115              0               0
# 1  NO STAND TAXI/FHV RELIEF STAND         115              0               0
# 2  NO STAND TAXI/FHV RELIEF STAND         115              0               0
# 3     PCKP DSCHRGE IN PRHBTD ZONE         115              0               0
# 4  NO STAND TAXI/FHV RELIEF STAND         115             10               0
#
#   reduction_amount payment_amount amount_due county  \
# 0                0            115          0     NY
# 1                0            115          0     NY
# 2                0            115          0     NY
# 3              115              0          0     NY
# 4               10            115          0     NY
#
#                 violation_status
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3        HEARING HELD-NOT GUILTY
# 4  HEARING HELD-GUILTY REDUCTION

# %%
#Cleaning Data

# %%
# Check the number of nan values
parking_df.isnull().sum()
# Out:
# plate                   0
# state                   0
# issue_date              0
# violation_time          0
# violation               0
# fine_amount             0
# penalty_amount          0
# interest_amount         0
# reduction_amount        0
# payment_amount          0
# amount_due              0
# county              25108
# violation_status    92857
# dtype: int64

# %%
#drop rows with more than 5 NaN values
parking_df_clean = parking_df[parking_df.isnull().sum(axis=1) <= 5]

#limit to 100,000 rows
parking_df_clean = parking_df_clean.head(100000)

# %%
parking_df_clean
# Out:
#           plate state               issue_date violation_time  \
# 0       AA96820    CT  2022-01-01T00:00:00.000         11:10A
# 1       GNV8795    NY  2022-01-01T00:00:00.000         11:42A
# 2        DFTE69    FL  2022-01-01T00:00:00.000         11:44A
# 3      T678645C    NY  2022-01-01T00:00:00.000         01:13A
# 4       67522MN    NY  2022-01-02T00:00:00.000         12:53P
# ...         ...   ...                      ...            ...
# 99995   12212ME    NY  2023-03-10T00:00:00.000         11:39A
# 99996   HSD9608    NY  2023-03-10T00:00:00.000         11:41A
# 99997   KSR1933    NY  2023-03-10T00:00:00.000         11:43A
# 99998   KTY3597    NY  2023-03-10T00:00:00.000         12:18P
# 99999    E85PCB    NJ  2023-03-10T00:00:00.000         12:03P
#
#                             violation fine_amount penalty_amount  \
# 0      NO STAND TAXI/FHV RELIEF STAND         115              0
# 1      NO STAND TAXI/FHV RELIEF STAND         115              0
# 2      NO STAND TAXI/FHV RELIEF STAND         115              0
# 3         PCKP DSCHRGE IN PRHBTD ZONE         115              0
# 4      NO STAND TAXI/FHV RELIEF STAND         115             10
# ...                               ...         ...            ...
# 99995       MOBILE BUS LANE VIOLATION         150              0
# 99996       MOBILE BUS LANE VIOLATION          50              0
# 99997       MOBILE BUS LANE VIOLATION          50              0
# 99998       MOBILE BUS LANE VIOLATION         100              0
# 99999       MOBILE BUS LANE VIOLATION         100              0
#
#       interest_amount reduction_amount payment_amount amount_due county  \
# 0                   0                0            115          0     NY
# 1                   0                0            115          0     NY
# 2                   0                0            115          0     NY
# 3                   0              115              0          0     NY
# 4                   0               10            115          0     NY
# ...               ...              ...            ...        ...    ...
# 99995               0                0            150          0     BK
# 99996               0                0             50          0    NaN
# 99997               0                0             50          0    NaN
# 99998               0                0            100          0    NaN
# 99999               0                0            100          0    NaN
#
#                     violation_status
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3            HEARING HELD-NOT GUILTY
# 4      HEARING HELD-GUILTY REDUCTION
# ...                              ...
# 99995  HEARING HELD-GUILTY REDUCTION
# 99996                            NaN
# 99997                            NaN
# 99998                            NaN
# 99999                            NaN
#
# [100000 rows x 13 columns]
# Warning: total number of rows (100000) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
parking_df_clean.to_csv('parking_violations.csv', index=False)
